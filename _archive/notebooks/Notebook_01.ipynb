# %% [markdown]
# # Here, we will be talking about a standard preprocessing pipeline

# %% [markdown]
# First lets load a speech signal

# %%
import librosa as lb
import torchaudio

audio_file = "Test.flac"
# waveform, sr = lb.load(audio_file, sr=None, mono=False)
# waveform = lb.to_mono(waveform)

waveform, sr = torchaudio.load(audio_file)

wa
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 8
#       4 audio_file = "Test.flac"
#       5 # waveform, sr = lb.load(audio_file, sr=None, mono=False)
#       6 # waveform = lb.to_mono(waveform)
# ----> 8 waveform, sr = torchaudio.load(audio_file)
#      10 wa
#
# File d:\Others\Miniconda\envs\speech-workspace\Lib\site-packages\torchaudio\__init__.py:86, in load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size, backend)
#      18 def load(
#      19     uri: Union[BinaryIO, str, os.PathLike],
#      20     frame_offset: int = 0,
#    (...)     26     backend: Optional[str] = None,
#      27 ) -> Tuple[torch.Tensor, int]:
#      28     """Load audio data from source using TorchCodec's AudioDecoder.
#      29
#      30     .. note::
#    (...)     84         by TorchCodec.
#      85     """
# ...

# %% [markdown]
# if the audio is stereo, you need to make it into mono
